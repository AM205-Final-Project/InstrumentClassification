# %% [markdown]
# # AM205: Final Project - December 2019
# ## Simon Warchol and Matthieu Meeus

# %%
import matplotlib.pyplot as plt
from scipy.fftpack import rfft, ifft
from scipy.io import wavfile
import numpy as np
from scipy.interpolate import lagrange

# %% [markdown]
# ## 1. FFT on simple, single-note sound files of different instruments

# %% [markdown]
# ### 1.1 Test

# %%
fs, data = wavfile.read('48028__smoseson__g2.wav') # load the data
data = data[:200000,:]
a = data.T[0] # this is a two channel soundtrack, I get the first track
#b=[(ele/2**8.)*2-1 for ele in a] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(a) # calculate fourier transform (complex numbers list)
plt.figure(figsize = (15,10))
plt.plot(np.linspace(0,fs,len(c)), abs(c))
plt.title('Cello G2 Note Frequency domain', fontsize = 25)
plt.xlabel('Frequency [Hz]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.show()

# %%
plt.figure(figsize = (15,10))
plt.plot(np.linspace(0,200000/fs, 200000), data.T[0])
plt.title('Cello G2 Note Time domain', fontsize = 25)
plt.xlabel('Time [s]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.show()

# %%
plt.plot(data.T[0])
plt.plot(data.T[1])

# %% [markdown]
# ### 1.2 All instruments

# %%
instruments = ['AcousticGuitar_C', 'CathedralOrgan_C', 'Clarinet_C', 'FrenchHorn_C', 'GrandPiano_C', 'Harp_C',
               'RockGuitar_C', 'Saxophone_C']
#, 'Guitar&FrenchHorn', 'GrandPiano&Clarinet']

# %%
# sampling a representative time frame for each instrument
samples = dict()

# saving the frequencies
freqs = dict()

plt.figure()
instrument = instruments[0]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# AcousticGuitar_C

# %%
plt.figure()
instrument = instruments[1]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# CathedralOrgan_C

# %%
plt.figure()
instrument = instruments[2]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

#sample selected = 3 to 4 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# Clarinet_C

# %%
plt.figure()
instrument = instruments[3]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# FrenchHorn_C

# %%
plt.figure()
instrument = instruments[4]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 0.7 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# GrandPiano_C

# %%
plt.figure()
instrument = instruments[5]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 0.7 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# Harp_C

# %%
plt.figure()
instrument = instruments[6]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 0.7 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# RockGuitar_C

# %%
plt.figure()
instrument = instruments[7]
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# Saxophone_C

# %%
# check influence of different samples

#1
start = 0*fs
end = int(1.5*fs)
sample1 = data.T[0][start:end]
plt.plot(np.linspace(start/fs, end/fs, (end-start)), sample1, label = 'Sample 1', c = 'blue')
start = int(1.5*fs)
end = 3*fs
sample2 = data.T[0][start:end]
plt.plot(np.linspace(start/fs, end/fs, (end-start)), sample2, label = 'Sample 2', c = 'red')
start = 3*fs
end = int(4.5*fs)
sample3 = data.T[0][start:end]
plt.plot(np.linspace(start/fs, end/fs, (end-start)), sample3, label = 'Sample 3', c = 'green')
t_length = data.shape[0]

plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend()
plt.show()

# %%
c = rfft(sample1) # calculate fourier transform (complex numbers list)
plt.plot(np.linspace(0,fs, len(c)), abs(c), label = 'Sample 1', c = 'blue', alpha = 0.6) 
c = rfft(sample2) # calculate fourier transform (complex numbers list)
plt.plot(np.linspace(0,fs, len(c)), abs(c), label = 'Sample 2', c = 'red', alpha = 0.6)     
c = rfft(sample3) # calculate fourier transform (complex numbers list)
plt.plot(np.linspace(0,fs, len(c)), abs(c), label = 'Sample 3', c = 'green', alpha = 0.6) 
plt.title('3 samples from RockGuitar in frequency domain')
plt.xlabel('Frequency [Hz]')
plt.ylabel('Magnitude')
plt.legend()
plt.xlim(0,5000)
plt.show()

# %%
mix_samples = dict()
plt.figure()
instrument = 'Guitar&FrenchHorn_C'
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
mix_samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), mix_samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# Guitar&FrenchHorn_C

# %%
plt.figure()
instrument = 'GrandPiano&Clarinet_C'
print(instrument)
fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
mix_samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), mix_samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# GrandPiano&Clarinet_C

# %%
plt.figure(figsize = (15,10))

for instrument in instruments[:4]:
    sample = samples[instrument]
    #b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
    c = rfft(sample) # calculate fourier transform (complex numbers list)
    fs = freqs[instrument]
    plt.plot(np.linspace(0,fs, len(c)), abs(c), label = instrument, alpha = 0.8) 
    
plt.title('All instruments in frequency domain', fontsize = 25)
plt.xlabel('Frequency [Hz]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.legend(fontsize= 25)
plt.xlim(0,5000)
plt.show()

# %% [markdown]
# ## Dive into FrenchHorn

# %%
plt.figure(figsize = (15,10))
instrument = 'FrenchHorn_C'
sample = samples[instrument]
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs[instrument]
plt.plot(np.linspace(0,fs, len(c)), abs(c), label = instrument, alpha = 0.8)     
plt.title('FrenchHorn in frequency domain', fontsize = 25)
plt.xlabel('Frequency [Hz]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.legend(fontsize= 25)
plt.xlim(0,5000)
plt.show()

# %%
fs, data = wavfile.read('sounds/FrenchHornOctave/A.wav') # load the data
start = 1*fs
end = 2*fs
t_length = data.shape[0]
A2_sample = data.T[0][start:end]
# plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
# plt.plot(np.linspace(start/fs, end/fs, (end-start)), A2_sample, label = 'Selected sample')
# plt.title(instrument + ' in Time domain', fontsize = 15)
# plt.xlabel('Time [s]', fontsize = 15)
# plt.ylabel('Magnitude', fontsize = 15)
# plt.legend(fontsize = 15)
# plt.show()

fs, data = wavfile.read('sounds/FrenchHornOctave/B.wav') # load the data
start = 1*fs
end = 2*fs
t_length = data.shape[0]
B2_sample = data.T[0][start:end]
# plt.figure()
# plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
# plt.plot(np.linspace(start/fs, end/fs, (end-start)), B2_sample, label = 'Selected sample')
# plt.title(instrument + ' in Time domain', fontsize = 15)
# plt.xlabel('Time [s]', fontsize = 15)
# plt.ylabel('Magnitude', fontsize = 15)
# plt.legend(fontsize = 15)
# plt.show()

fs, data = wavfile.read('sounds/FrenchHornOctave/C.wav') # load the data
start = 1*fs
end = 2*fs
t_length = data.shape[0]
C2_sample = data.T[0][start:end]
plt.figure()
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), C2_sample, label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()


plt.figure(figsize = (15,10))
c_A2 = rfft(A2_sample) # calculate fourier transform (complex numbers list)
plt.plot(np.linspace(0,fs, len(c_A2)), abs(c_A2), label = 'A2', alpha = 0.8)   
c_B2 = rfft(B2_sample) # calculate fourier transform (complex numbers list)
plt.plot(np.linspace(0,fs, len(c_B2)), abs(c_B2), label = 'B2', alpha = 0.8)     
c_C2 = rfft(C2_sample) # calculate fourier transform (complex numbers list)
plt.plot(np.linspace(0,fs, len(c_C2)), abs(c_C2), label = 'C2', alpha = 0.8)  
plt.title('FrenchHorn in frequency domain', fontsize = 25)
plt.xlabel('Frequency [Hz]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.legend(fontsize= 25)
plt.xlim(0,5000)
plt.show()

# %%
# find the top freq for each note, lets say higher than 10e7
threshold = 10e6
top_freq_A2 = []
c_A2 = abs(c_A2)
for i, magn in enumerate(c_A2):
    freq = np.linspace(0,fs, len(c_A2))[i]
    if magn >= threshold:
        freq = np.linspace(0,fs, len(c_A2))[i]
        if (len(top_freq_A2) == 0) or (abs(freq - top_freq_A2[-1])>20):
            top_freq_A2.append(freq)
            
print(top_freq_A2)

threshold = 10e6
top_freq_B2 = []
c_B2 = abs(c_B2)
for i, magn in enumerate(c_B2):
    freq = np.linspace(0,fs, len(c_B2))[i]
    if magn >= threshold:
        freq = np.linspace(0,fs, len(c_B2))[i]
        if (len(top_freq_B2) == 0) or (abs(freq - top_freq_B2[-1])>20):
            top_freq_B2.append(freq)
            
print(top_freq_B2 )
# Out:
# [439.0099548742602, 876.0198643960181, 1313.0297739177759, 1751.0397061157848, 2196.049797047552, 2637.0597972743144, 3077.069774824826, 3517.079752375337, 3957.0897299258486, 5717.129640127894]
# [493.01117939182296, 984.0223134311435, 1475.0334474704641, 1971.0446948910405, 2471.0560330166218, 3456.0783691240163, 3953.0896392208438, 4441.100705231411]

# %%
plt.scatter([439.0099548742602, 876.0198643960181, 1313.0297739177759, 1751.0397061157848, 
             2196.049797047552, 2637.0597972743144, 3077.069774824826, 3517.079752375337],
           [493.01117939182296, 984.0223134311435, 1475.0334474704641, 1971.0446948910405, 
            2471.0560330166218, 3456.0783691240163, 3953.0896392208438, 4441.100705231411])
plt.xlabel('Peak frequency FrenchHorn A2')
plt.ylabel('Peak frequency FrenchHorn B2')
# Out:
# Text(0, 0.5, 'Peak frequency FrenchHorn B2')

# %%
np.sum(c_A2 >= 10e6)
# Out:
# 43

# %%
plt.figure(figsize = (7,4))

sample = samples['AcousticGuitar']
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs['AcousticGuitar']

fig, ax = plt.subplots(1,2, figsize=(20,7))
ax[0].plot(np.linspace(0,fs, len(c)), abs(c), label = 'AcousticGuitar', alpha = 0.8) 
ax[0].set_title('All instruments in frequency domain', fontsize = 25)
ax[0].set(xlabel='Frequency [Hz]', ylabel='Magnitude')
ax[0].set_xlim(0,5000)
ax[0].legend(fontsize= 25)

sample = samples['FrenchHorn']
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs['FrenchHorn']
ax[1].plot(np.linspace(0,fs, len(c)), abs(c), label = 'FrenchHorn', alpha = 0.8) 
    
ax[1].set_title('All instruments in frequency domain', fontsize = 25)
ax[1].set(xlabel='Frequency [Hz]', ylabel='Magnitude')
ax[1].legend(fontsize= 25)
ax[1].set_xlim(0,5000)

fig, ax = plt.subplots(figsize=(20,7))

sample = samples['Guitar&FrenchHorn']
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)


fs = freqs['Guitar&FrenchHorn']

ax.plot(np.linspace(0,fs, len(c)), abs(c), label = 'Guitar&FrenchHorn', alpha = 0.8) 
    
ax.set_title('All instruments in frequency domain', fontsize = 25)
ax.set(xlabel='Frequency [Hz]', ylabel='Magnitude')
ax.set_xlim(0,5000)
ax.legend(fontsize= 25)

# %%
plt.figure(figsize = (15,10))
sample = samples['AcousticGuitar']
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs['AcousticGuitar']

plt.plot(np.linspace(0,fs, len(c)), abs(c), label = 'AcousticGuitar', alpha = 0.5) 

sample = samples['FrenchHorn']
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs['FrenchHorn']
plt.plot(np.linspace(0,fs, len(c)), abs(c), label = 'FrenchHorn', alpha = 0.5) 
    
sample = samples['Guitar&FrenchHorn']
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)


fs = freqs['Guitar&FrenchHorn']

plt.plot(np.linspace(0,fs, len(c)), abs(c), label = 'Guitar&FrenchHorn', alpha = 0.5) 
    
plt.title('All instruments in frequency domain', fontsize = 25)
plt.xlabel('Frequency [Hz]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.legend(fontsize= 25)
plt.xlim(0,5000)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-122-c069f22e29ab> in <module>
#       1 plt.figure(figsize = (15,10))
# ----> 2 sample = samples['AcousticGuitar']
#       3 #b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
#       4 c = rfft(sample) # calculate fourier transform (complex numbers list)
#       5 fs = freqs['AcousticGuitar']
#
# KeyError: 'AcousticGuitar'

# %%
def peak_finding(fs, magnitudes, n = 10):
    # find the top freq for each note, lets say higher than 10e7
    threshold = 1e4
    freqs = np.linspace(0,fs, len(magnitudes))
    top_freq = []
    top_magn = []
    for i, magn in enumerate(magnitudes):
        if magn >= threshold:
            freq = freqs[i]
            if len(top_freq) >= 1 and (abs(freq - top_freq[-1])<=30):
                if magn > top_magn[-1]:
                    top_magn[-1] = magn
                    top_freq[-1] = freq
            else:
                top_freq.append(freq)
                top_magn.append(magn)
                
    idx = np.array(top_magn).argsort()[::-1][:n]
    top_freq_sorted = np.array(top_freq)[idx]
    top_magn_sorted = np.array(top_magn)[idx]
    
    # convert back to increasing f
    idx = np.array(top_freq_sorted).argsort()[:n]
    top_freq_sorted = np.array(top_freq_sorted)[idx]
    top_magn_sorted = np.array(top_magn_sorted)[idx]
                               
    return top_freq_sorted, top_magn_sorted

# %%
top_freq, top_magn = peak_finding(fs, abs(c))
print(top_freq)
# Out:
# [ 260.25147535  522.0029592   785.50445297 1047.50593824 1309.25742209
#  1571.25890736 1833.01039122 2095.01187648 2356.76336034 2619.01484702]

# %%
plt.figure(figsize = (15,10))
plt.scatter(top_freq, top_magn, label = 'Peaks found')
plt.plot(np.linspace(0,fs, len(c)), abs(c), label = 'Guitar&FrenchHorn', alpha = 0.8)   
plt.title('All instruments in frequency domain', fontsize = 25)
plt.xlabel('Frequency [Hz]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.legend(fontsize= 25)
plt.xlim(0,5000)
# Out:
# (0, 5000)

# %%
# let's try poly fit
top_magn = [k/1e8 for k in top_magn]
top_freq = [k/5000.0 for k in top_freq]

# %%
poly = np.polyfit(top_freq, top_magn, deg = 6)
poly_f = np.poly1d(poly)

g = np.array([poly_f(k) for k in np.linspace(0,1,len(c))])

plt.figure(figsize = (15,10))
plt.scatter(top_freq, top_magn, label = 'Peaks found')
#plt.plot(np.linspace(0,1, len(c)), abs(c)/1e8, label = 'Guitar&FrenchHorn', alpha = 0.8)  
plt.plot(np.linspace(0,1,len(c)), g, label = 'Polynomial fit')
plt.title('All instruments in frequency domain', fontsize = 25)
plt.xlabel('Frequency [Hz]', fontsize = 25)
plt.ylabel('Magnitude', fontsize = 25)
plt.legend(fontsize= 25)
plt.ylim()
print(poly)
# Out:
# [ 6.56602292e+04 -1.14996171e+05  7.86442088e+04 -2.65343761e+04
#   4.57861993e+03 -3.76863704e+02  1.29781454e+01]

# %% [markdown]
# ## Let's find the peak freqs of all instruments

# %%
dict_peaks = dict()

for instrument in instruments:
    sample = samples[instrument]
    #b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
    c = rfft(sample) # calculate fourier transform (complex numbers list)
    fs = freqs[instrument]
    plt.figure(figsize = (10,8))
    plt.plot(np.linspace(0,fs, len(c)), abs(c), alpha = 0.8) 
    top_freq, top_magn = peak_finding(fs, abs(c))
    dict_peaks[instrument] = top_freq
    plt.scatter(top_freq, top_magn, label = 'Peaks found')
    plt.title(instrument, fontsize = 15)
    plt.xlabel('Frequency [Hz]', fontsize = 15)
    plt.ylabel('Magnitude', fontsize = 15)
    plt.legend(fontsize= 15)
    plt.xlim(0,5000)
    plt.show()

# %%
# let's now find the peaks of the combo and loop through the instruments
peaks_combo = dict_peaks['Guitar&FrenchHorn']
for instrument in instruments[:-1]:
    peaks = dict_peaks[instrument]
    lst_ones_zeros = np.zeros(len(peaks))
    for i, peak_i in enumerate(peaks):
        for peak_c in peaks_combo:
            if abs(peak_c - peak_i) <= 0.1:
                lst_ones_zeros[i] = 1
    print('For {}, we found {} peak frequencies in the combo'.format(instrument, np.sum(lst_ones_zeros)))
# Out:
# For AcousticGuitar, we found 2.0 peak frequencies in the combo
# For CathedralOrgan, we found 0.0 peak frequencies in the combo
# For Clarinet, we found 0.0 peak frequencies in the combo
# For FrenchHorn, we found 8.0 peak frequencies in the combo
# For GrandPiano, we found 1.0 peak frequencies in the combo
# For Harp, we found 0.0 peak frequencies in the combo
# For RockGuitar, we found 0.0 peak frequencies in the combo
# For Saxophone, we found 0.0 peak frequencies in the combo
# For Guitar&FrenchHorn, we found 10.0 peak frequencies in the combo

# %%
plt.figure()
instrument = 'GrandPiano&Clarinet'
print(instrument)
fs, data = wavfile.read('sounds/'+instrument+'.wav') # load the data
freqs[instrument] = fs

# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
#plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()
# Out:
# GrandPiano&Clarinet

# %%
#b=[(ele/2**8.)*2-1 for ele in sample] # this is 8-bit track, b is now normalized on [-1,1)
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs[instrument]
plt.figure(figsize = (10,8))
plt.plot(np.linspace(0,fs, len(c)), abs(c), alpha = 0.8) 
top_freq, top_magn = peak_finding(fs, abs(c))
dict_peaks[instrument] = top_freq
plt.scatter(top_freq, top_magn, label = 'Peaks found')
plt.title(instrument, fontsize = 15)
plt.xlabel('Frequency [Hz]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize= 15)
plt.xlim(0,5000)
plt.show()

# %%
# let's now find the peaks of the combo and loop through the instruments
peaks_combo = dict_peaks['GrandPiano&Clarinet']
for instrument in instruments[:-1]:
    peaks = dict_peaks[instrument]
    lst_ones_zeros = np.zeros(len(peaks))
    for i, peak_i in enumerate(peaks):
        for peak_c in peaks_combo:
            if abs(peak_c - peak_i) <= 10:
                lst_ones_zeros[i] = 1
    print('For {}, we found {} peak frequencies in the combo'.format(instrument, np.sum(lst_ones_zeros)))
# Out:
# For AcousticGuitar, we found 7.0 peak frequencies in the combo
# For CathedralOrgan, we found 1.0 peak frequencies in the combo
# For Clarinet, we found 8.0 peak frequencies in the combo
# For FrenchHorn, we found 7.0 peak frequencies in the combo
# For GrandPiano, we found 8.0 peak frequencies in the combo
# For Harp, we found 6.0 peak frequencies in the combo
# For RockGuitar, we found 6.0 peak frequencies in the combo
# For Saxophone, we found 9.0 peak frequencies in the combo
# For Guitar&FrenchHorn, we found 9.0 peak frequencies in the combo

# %%
instrument = 'Clarinet'                       
sample = samples[instrument]
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs[instrument]
top_freq, top_magn = peak_finding(fs, abs(c))
dict_peaks[instrument] = top_freq
plt.plot(range(1,11), top_freq)
plt.show()

# %% [markdown]
# ## Let's try with linear least squares

# %%
print(instruments)
# Out:
# ['AcousticGuitar', 'CathedralOrgan', 'Clarinet', 'FrenchHorn', 'GrandPiano', 'Harp', 'RockGuitar', 'Saxophone', 'Guitar&FrenchHorn', 'GrandPiano&Clarinet']

# %%
instruments = instruments[:-2]

# %%
# compute A
A = np.zeros((len(c), len(instruments)))
for i, instrument in enumerate(instruments):
    sample = samples[instrument]
    c = rfft(sample) # calculate fourier transform (complex numbers list)
    fs = freqs[instrument] 
    print(len(c))
    A[:,i] = abs(c)
# Out:
# 176400
# 176400
# 176400
# 176400
# 176400
# 176400
# 176400
# 176400

# %%
# compute b
sample = samples['GrandPiano&Clarinet']
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs[instrument] 
b = abs(c)

# %%
A.shape
# Out:
# (176400, 8)

# %%
b.shape
# Out:
# (176400,)

# %%
x = np.linalg.lstsq(A,b)[0]
# Out:
# C:\Users\Matthieu\Pictures\Anaconda3_2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.

# %%
x
# Out:
# array([ 0.0174321 , -0.0209994 ,  0.49020096, -0.04278293,  0.95801986,
#        -0.01027909, -0.00741543, -0.01227416])

# %%
print(instruments[2])
print(instruments[4])
# Out:
# Clarinet
# GrandPiano

# %%
sample = samples['Guitar&FrenchHorn']
c = rfft(sample) # calculate fourier transform (complex numbers list)
fs = freqs[instrument] 
b = abs(c)

# %%
x = np.linalg.lstsq(A,b)[0]
# Out:
# C:\Users\Matthieu\Pictures\Anaconda3_2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   """Entry point for launching an IPython kernel.

# %%
x
# Out:
# array([ 0.96862827,  0.01268244, -0.008542  ,  0.71469271,  0.02168073,
#        -0.03536389, -0.03074802,  0.00145718])

# %%
print(instruments[0])
print(instruments[3])
# Out:
# AcousticGuitar
# FrenchHorn

# %%
# let's formalize this
def lls_instruments(mix, instruments, n_instr = None):
    '''
    Input:
    - mix : sound sample
    - instruments : dictionary of the available data of instruments
    - n_instr : number of instruments expected
                when None, the algorithm will come up with its best guess
    '''
    # convert sound sampel to freq domain
    c_mix = rfft(mix)
    b = abs(c_mix) 
    
    # compose A
    A = np.zeros((len(c_mix), len(instruments)))
    instr_list = []
    for i, instrument in enumerate(instruments):
        instr_list.append(instrument)
        sample = samples[instrument]
        c = rfft(sample) 
        A[:,i] = abs(c)  
        
    x = np.linalg.lstsq(A,b,rcond=None)[0]
    
    # sort from large to small
    idx = x.argsort()[::-1]
    coef_sorted = x[idx]
    instr_sorted = np.array(instr_list)[idx]
    
    if n_instr is not None:
        return instr_sorted[:n_instr]
    else:
        # at least two
        instr_incl = [instr_sorted[0], instr_sorted[1]]
        first_drop = abs(coef_sorted[0] - coef_sorted[1])
        # check if drop is not too big
        for i in range(2, len(instr_sorted)):
            if abs(coef_sorted[i] - coef_sorted[i-1]) >= 2*first_drop:
                break
            else:
                instr_incl.append(instr_sorted[i])
            
    return instr_incl

# %%
# adding sampel with three instruments
plt.figure()
instrument = 'GuitarFrenchHornPiano'
fs, data = wavfile.read('sounds/'+instrument+'.wav') # load the data
# sample selected = 1 to 2 sec
start = 0*fs
end = 4*fs
samples[instrument] = data.T[0][start:end]
t_length = data.shape[0]
plt.plot(np.linspace(0,t_length/fs, t_length), data.T[0], label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples[instrument], label = 'Selected sample')
plt.title(instrument + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
print(lls_instruments(samples['Guitar&FrenchHorn'], instruments, n_instr = 2))
print(lls_instruments(samples['GrandPiano&Clarinet'], instruments, n_instr = 2))
print(lls_instruments(samples['GuitarFrenchHornPiano'], instruments, n_instr = 3))
# Out:
# C:\Users\Matthieu\Pictures\Anaconda3_2\lib\site-packages\ipykernel_launcher.py:23: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
# ['AcousticGuitar' 'FrenchHorn']
# ['GrandPiano' 'Clarinet']
# ['Harp' 'Clarinet' 'AcousticGuitar']

# %% [markdown]
# ## Sparse regression

# %% [markdown]
# If we know that not all features play a role in the model, we can use the mathematics of sparse regression to drive specific coefficients - of non relevant information - to zero. Recall we can write the linear least square problem as:
#
# $$Ax = b$$ and $$x = argmin_x (||Ax - b||^2)$$
#
# For this equation, a closed form solution named the 'normal equations' was available to compute the best x:
#
# $$\hat x = (A A^T)^{-1}A^T b$$
#
# From literature we know that $l_1$ regularization can drive the non-relevant coefficients to zero. Or mathematically, the equation now becomes:
#
# $$x = argmin_x (||Ax - b||^2 + \lambda||x||_1)$$
#
# The inclusion of $\lambda||x||_1$ in the expression to be minimized leads to a penalization of large coefficient values. The larger $\lambda$, the harder this penalization and thus the more the not-contributing feature coefficients will be driven towards zero. Note that this expression is not straight-froward anymore to optimize, as the $l_1$ norm makes it not differentiable.
#
# The expression can be rewritten as:
#
# $$x = argmin_x (x^Tx - 2x^TA^Tb + b^Tb + \lambda||x||_1)$$
#
# The solution of this corresponds to the one $x$ for which the gradient of the expression between brackets is equal to zero. The gradient of $||x||_1$ is defined at all points except for $x_i = 0$. Therefore, the partial derivatives with respect to $x_i$ can be written as:
#
# $$ \left(
#   \begin{array}{cccc}
#   2x_i - 2A_i^Tb + \lambda <=> x_i > 0 \\
#   [-\lambda,\lambda] - 2A_i^Tb <=> x_i = 0 \\
#    2x_i - 2A_i^Tb - \lambda <=> x_i < 0 \\
#   \end{array}
# \right)$$
#
# Note that $[-\lambda, \lambda]$ means that the value can be any value inside the interval. Setting this partial derivative equal to zero, while keeping in mind the constraint on $x_i$, we get the following expression for all $x_i$ values:
#
# $$\left(
#   \begin{array}{cccc}
#   0 <=> \lambda > 2|A_i^Tb| \\
#   A_i^Tb - sign(A_i^Tb)\frac{\lambda}{2} <=> \lambda \leq 2|A_i^Tb|\\
#   \end{array}
# \right)$$
#
# Intuitively, this makes sense. The value $A_i^Tb$ is related with the correlation of feature i and response variable b. If this correlation is below a certain threshold $\lambda$, its coefficient is set to 0. This sparse regression can now be implemented for our instrument case.

# %%
from sklearn.linear_model import LassoCV

# let's formalize this
def lasso_instruments_skl(mix, instruments, n_instr):
    '''
    Input:
    - mix : sound sample
    - instruments : dictionary of the available data of instruments
    - n_instr : number of instruments expected
                when None, the algorithm will come up with its best guess
    - lam_list : list of regularization params
    '''
    # convert sound sampel to freq domain
    c_mix = rfft(mix)
    b = abs(c_mix) 
    
    # compose A
    A = np.zeros((len(c_mix), len(instruments)))
    instr_list = []
    for i, instrument in enumerate(instruments):
        instr_list.append(instrument)
        sample = samples[instrument]
        c = rfft(sample) 
        A[:,i] = abs(c)  
    
    # run through lambda values until only n_instr 
    model = LassoCV(cv = 3)
    model.fit(A,b)
    coefs = model.coef_
    idx = np.array(coefs).argsort()[::-1]
    coef_sorted = np.array(coefs)[idx]
    instr_sorted = np.array(instr_list)[idx]
    return coef_sorted[:n_instr], instr_sorted[:n_instr],

# %%
# let's formalize this
def lasso_instruments(mix, instruments, n_instr, lam_list = np.linspace(1e16, 1e18, 100)):
    '''
    Input:
    - mix : sound sample
    - instruments : dictionary of the available data of instruments
    - n_instr : number of instruments expected
                when None, the algorithm will come up with its best guess
    - lam_list : list of regularization params
    '''
    # convert sound sampel to freq domain
    c_mix = rfft(mix)
    b = abs(c_mix) 
    
    # compose A
    A = np.zeros((len(c_mix), len(instruments)))
    instr_list = []
    for i, instrument in enumerate(instruments):
        instr_list.append(instrument)
        sample = samples[instrument]
        c = rfft(sample) 
        A[:,i] = abs(c)  
    
    # run through lambda values until only n_instr 
    
    for lam in lam_list:
        # compute the coefficient following the above-described procedure
        coefs = []
        for i in range(len(instruments)):
            corr = 2*abs(np.dot(A[:,i],b))
            if corr < lam:
                coefs.append(0)
            else:
                coefs.append(np.dot(A[:,i],b) - lam/2*np.sign(np.dot(A[:,i],b)))     
        if np.sum(np.array(coefs) > 0.0) == n_instr:
            break
    
    # sort from large to small
    idx = np.array(coefs).argsort()[::-1]
    coef_sorted = np.array(coefs)[idx]
    instr_sorted = np.array(instr_list)[idx]
            
    return coef_sorted[:n_instr], instr_sorted[:n_instr], lam

# %%
print(lasso_instruments(samples['Guitar&FrenchHorn'], instruments, n_instr = 2))
print(lasso_instruments(samples['GrandPiano&Clarinet'], instruments, n_instr = 2))
print(lasso_instruments(samples['GuitarFrenchHornPiano'], instruments, n_instr = 3))
# Out:
# (array([2.07191324e+17, 1.01675967e+17]), array(['FrenchHorn', 'AcousticGuitar'], dtype='<U14'), 5.020240480961924e+17)
# (array([1.97437061e+17, 1.74746356e+15]), array(['Clarinet', 'Saxophone'], dtype='<U14'), 4.66312625250501e+17)
# (array([4.69701263e+16, 1.54189014e+16, 4.05997154e+15]), array(['Clarinet', 'Harp', 'AcousticGuitar'], dtype='<U14'), 5.959919839679358e+16)

# %% [markdown]
# ## Add more notes for piano

# %%
notes = ['A', 'Asharp','B', 'C','Csharp','D', 'Dsharp','E','F','Fsharp','G','Gsharp']

# %%
del samples['frenchhorn_C']

# %%
samples.keys()
# Out:
# dict_keys(['AcousticGuitar_C', 'CathedralOrgan_C', 'Clarinet_C', 'FrenchHorn_C', 'GrandPiano_C', 'Harp_C', 'RockGuitar_C', 'Saxophone_C', 'piano_A', 'guitar_A', 'frenchhorn_A', 'piano_Asharp', 'guitar_Asharp', 'frenchhorn_Asharp', 'piano_B', 'guitar_B', 'frenchhorn_B', 'piano_C', 'guitar_C', 'piano_Csharp', 'guitar_Csharp', 'frenchhorn_Csharp', 'piano_D', 'guitar_D', 'frenchhorn_D', 'piano_Dsharp', 'guitar_Dsharp', 'frenchhorn_Dsharp', 'piano_E', 'guitar_E', 'frenchhorn_E', 'piano_F', 'guitar_F', 'frenchhorn_F', 'piano_Fsharp', 'guitar_Fsharp', 'frenchhorn_Fsharp', 'piano_G', 'guitar_G', 'frenchhorn_G', 'piano_Gsharp', 'guitar_Gsharp', 'frenchhorn_Gsharp'])

# %%
samples = dict()
instr_c = ['AcousticGuitar_C', 'CathedralOrgan_C', 'Clarinet_C', 'FrenchHorn_C', 'GrandPiano_C', 'Harp_C',
               'RockGuitar_C', 'Saxophone_C']
for instrument in instr_c:
    fs, data = wavfile.read('sounds/'+instrument[:-2]+'.wav') # load the data
    start = 0*fs
    end = 4*fs
    samples[instrument] = data.T[0][start:end]

for note in notes:
    fs, data = wavfile.read('sounds/PianoOctave/'+note+'.wav') # load the data
    start = 0*fs
    end = 4*fs
    samples['GrandPiano_'+ note] = data.T[0][start:end]
    fs, data = wavfile.read('sounds/AcousticGuitarOctave/'+note+'.wav') # load the data
    samples['AcousticGuitar_'+ note] = data.T[0][start:end]
    fs, data = wavfile.read('sounds/FrenchHornOctave/'+note+'.wav') # load the data
    samples['FrenchHorn_'+ note] = data.T[0][start:end]

# %%
fs, data = wavfile.read('sounds/GuitarFrenchHornPiano'+'.wav')
mix_samples['GuitarFrenchHornPiano'] = data.T[0][start:end]
fs, data = wavfile.read('sounds/AcousticGuitarDFrenchHornFSharpGrandPianoA.wav')
mix_samples['AcousticGuitarDFrenchHornFSharpGrandPianoA'] = data.T[0][start:end]
fs, data = wavfile.read('sounds/Youtube/Mary-FH-MjpAvGl_xM0.wav')
mix_samples['Mary_FrenchHorn'] = data[start:end]
fs, data = wavfile.read('sounds/Youtube/Mary-cD6sq7TjZAw.wav')
mix_samples['Mary_piano'] = data.T[0][start:end]
fs, data = wavfile.read('sounds/2Guitar2FrenchHorn2GrandPiano.wav')
mix_samples['Mixof6'] = data.T[0][start:end]
mix_samples.keys()
# Out:
# C:\Users\Matthieu\Pictures\Anaconda3_2\lib\site-packages\scipy\io\wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# dict_keys(['Guitar&FrenchHorn_C', 'GrandPiano&Clarinet_C', 'GuitarFrenchHornPiano', 'AcousticGuitarDFrenchHornFSharpGrandPianoA', 'Mary_FrenchHorn', 'Mary_piano', 'Mixof6'])

# %%
samples.keys()
# Out:
# dict_keys(['AcousticGuitar_C', 'CathedralOrgan_C', 'Clarinet_C', 'FrenchHorn_C', 'GrandPiano_C', 'Harp_C', 'RockGuitar_C', 'Saxophone_C', 'GrandPiano_A', 'AcousticGuitar_A', 'FrenchHorn_A', 'GrandPiano_Asharp', 'AcousticGuitar_Asharp', 'FrenchHorn_Asharp', 'GrandPiano_B', 'AcousticGuitar_B', 'FrenchHorn_B', 'GrandPiano_Csharp', 'AcousticGuitar_Csharp', 'FrenchHorn_Csharp', 'GrandPiano_D', 'AcousticGuitar_D', 'FrenchHorn_D', 'GrandPiano_Dsharp', 'AcousticGuitar_Dsharp', 'FrenchHorn_Dsharp', 'GrandPiano_E', 'AcousticGuitar_E', 'FrenchHorn_E', 'GrandPiano_F', 'AcousticGuitar_F', 'FrenchHorn_F', 'GrandPiano_Fsharp', 'AcousticGuitar_Fsharp', 'FrenchHorn_Fsharp', 'GrandPiano_G', 'AcousticGuitar_G', 'FrenchHorn_G', 'GrandPiano_Gsharp', 'AcousticGuitar_Gsharp', 'FrenchHorn_Gsharp'])

# %%
print(lls_instruments(mix_samples['Guitar&FrenchHorn_C'], samples.keys(), n_instr = 2))
print(lasso_instruments(mix_samples['Guitar&FrenchHorn_C'], samples.keys(), n_instr = 2))
# Out:
# ['AcousticGuitar_C' 'FrenchHorn_C']
# (array([1.30618085e+17, 5.14179901e+16]), array(['FrenchHorn_C', 'AcousticGuitar_C'], dtype='<U21'), 5.1e+17)

# %%
print(lls_instruments(mix_samples['GrandPiano&Clarinet_C'], samples.keys(), n_instr = 2))
print(lasso_instruments_skl(mix_samples['GrandPiano&Clarinet_C'], samples.keys(), n_instr = 2))
# Out:
# ['Clarinet_C' 'GrandPiano_C']
# (array([0.5169564 , 0.22847113]), array(['Clarinet_C', 'GrandPiano_C'], dtype='<U21'))

# %%
print(lls_instruments(mix_samples['GuitarFrenchHornPiano'], samples.keys(), n_instr = 3))
print(lasso_instruments_skl(mix_samples['GuitarFrenchHornPiano'], samples.keys(), n_instr = 3))
# Out:
# ['GrandPiano_G' 'AcousticGuitar_Csharp' 'FrenchHorn_E']
# (array([0.46713801, 0.42970508, 0.36608022]), array(['GrandPiano_G', 'FrenchHorn_E', 'AcousticGuitar_Csharp'],
#       dtype='<U21'))

# %%
print(lls_instruments(mix_samples['AcousticGuitarDFrenchHornFSharpGrandPianoA'], samples.keys(), n_instr = 3))
print(lasso_instruments_skl(mix_samples['AcousticGuitarDFrenchHornFSharpGrandPianoA'], samples.keys(), n_instr = 3))
# Out:
# ['GrandPiano_A' 'AcousticGuitar_D' 'FrenchHorn_Fsharp']
# (array([0.61894003, 0.47049882, 0.27581609]), array(['GrandPiano_A', 'AcousticGuitar_D', 'FrenchHorn_Fsharp'],
#       dtype='<U21'))

# %%
print(lls_instruments(mix_samples['Mixof6'], samples.keys(), n_instr = 6))
print(lasso_instruments_skl(mix_samples['Mixof6'], samples.keys(), n_instr = 6))
# Out:
# ['GrandPiano_A' 'AcousticGuitar_D' 'GrandPiano_Asharp' 'FrenchHorn_Gsharp'
#  'AcousticGuitar_Csharp' 'FrenchHorn_Dsharp']
# (array([0.34952692, 0.31360482, 0.31166473, 0.21115948, 0.20919846,
#        0.168337  ]), array(['GrandPiano_A', 'FrenchHorn_Gsharp', 'AcousticGuitar_D',
#        'AcousticGuitar_Csharp', 'GrandPiano_Asharp', 'FrenchHorn_Dsharp'],
#       dtype='<U21'))

# %%
# real world 
print(lls_instruments(mix_samples['Mary_FrenchHorn'], samples.keys(), n_instr = 4))
print(lasso_instruments_skl(mix_samples['Mary_FrenchHorn'], samples.keys(), n_instr = 4))
# Out:
# ['GrandPiano_D' 'FrenchHorn_D' 'GrandPiano_G' 'GrandPiano_C']
# (array([0.34626176, 0.32173365, 0.24069142, 0.19240348]), array(['GrandPiano_D', 'FrenchHorn_D', 'GrandPiano_G', 'GrandPiano_C'],
#       dtype='<U21'))

# %%
print(lls_instruments(mix_samples['Mary_piano'], samples.keys(), n_instr = 4))
print(lasso_instruments_skl(mix_samples['Mary_piano'], samples.keys(), n_instr = 4))
# Out:
# ['GrandPiano_D' 'GrandPiano_E' 'Harp_C' 'GrandPiano_Dsharp']
# (array([0.13463647, 0.09313905, 0.06991269, 0.04056398]), array(['GrandPiano_D', 'GrandPiano_E', 'Harp_C', 'GrandPiano_Dsharp'],
#       dtype='<U21'))

# %%
fs, data = wavfile.read('sounds/Youtube/marySongOrig.wav')

# %%
start = 3*fs
end = 7*fs
samples['marySongOrig'] = data[start:end]
t_length = len(data)
plt.plot(np.linspace(0,t_length/fs, t_length), data, label = 'Entire recording')
plt.plot(np.linspace(start/fs, end/fs, (end-start)), samples['marySongOrig'], label = 'Selected sample')
plt.title('marySongOrig' + ' in Time domain', fontsize = 15)
plt.xlabel('Time [s]', fontsize = 15)
plt.ylabel('Magnitude', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
print(lasso_instruments(samples['marySongOrig'], ['piano_'+ note for note in piano_notes], n_instr = 4))
# Out:
# (array([2.68730729e+16, 1.09877904e+16, 8.88682435e+15, 2.38506070e+15]), array(['piano_Asharp', 'piano_Gsharp', 'piano_F', 'piano_Dsharp'],
#       dtype='<U12'), 3e+16)

# %% [markdown]
# ## PCA

# %%
# compose A
options = samples.keys()
A = np.zeros((len(c), len(options)))
for i, instrument in enumerate(options):
    sample = samples[instrument]
    c = rfft(sample) 
    A[:,i] = abs(c)

mean = A.mean(axis = 1)
print(mean.shape)

for i in range(A.shape[1]):
    A[:,i] = A[:,i] - mean
# Out:
# (176400,)

# %%
plt.plot(np.linspace(0,fs,A.shape[0]), mean)
plt.xlim(0,5000)
# Out:
# (0, 5000)

# %%
from sklearn.decomposition import SparsePCA

# %%
X.shape
# Out:
# (176400, 30)

# %%
U, S, Vh = np.linalg.svd(A, full_matrices = False)

# %%
S
# Out:
# array([1.40686203e+09, 1.28477041e+09, 1.18635028e+09, 1.01988168e+09,
#        9.69334136e+08, 8.41157716e+08, 8.05883599e+08, 7.92529195e+08,
#        7.47671461e+08, 7.27447282e+08, 7.11366757e+08, 6.60464145e+08,
#        6.47818679e+08, 6.30986299e+08, 5.94298109e+08, 5.43967659e+08,
#        5.28667651e+08, 5.23639621e+08, 4.81425702e+08, 4.61826486e+08,
#        4.46782240e+08, 4.28560179e+08, 4.15500439e+08, 3.94046148e+08,
#        3.88083437e+08, 3.79682353e+08, 3.59411899e+08, 3.50790075e+08,
#        3.47066450e+08, 3.35139742e+08, 3.18447925e+08, 2.90095873e+08,
#        2.85108706e+08, 2.82190554e+08, 2.59347537e+08, 2.55057490e+08,
#        2.29946257e+08, 2.21212505e+08, 2.15074190e+08, 1.98298344e+08,
#        2.15920341e-06])

# %%
U.shape
# Out:
# (176400, 41)

# %%
plt.figure(figsize = (15,10))
for i in range(10):
    plt.plot(np.linspace(0,fs,U.shape[0]), U[:,i])
plt.xlim(0,5000)
# Out:
# (0, 5000)

# %% [markdown]
# ## Combine peak finding with LLS

# %%
options = samples.keys()
A_peaks = np.zeros((50,len(options)))
for i, instrument in enumerate(options):
    sample = samples[instrument]
    c = rfft(sample) 
    top_freq, top_magn = peak_finding(fs, c, n = 50)
    A_peaks[:,i] = top_freq

# %%
mix = mix_samples['AcousticGuitarDFrenchHornFSharpGrandPianoA']
c = rfft(mix)
top_freq, top_magn = peak_finding(fs, c, n = 50)
b = top_freq
x = np.linalg.lstsq(A_peaks,b,rcond=None)[0]

# %%
len(x)
# Out:
# 41

# %%
idx = np.array(x).argsort()[::-1]
coef_sorted = np.array(x)[idx]
instr_sorted = np.array(list(options))[idx]

# %%
instr_sorted[:3]
# Out:
# array(['GrandPiano_Gsharp', 'FrenchHorn_D', 'FrenchHorn_A'], dtype='<U21')
